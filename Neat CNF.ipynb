# %%
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import scipy as sp

# %%
# [CNF] = 0.01wt.% at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_75deg_1 = cnf001_75deg_1.iloc[:,0]
corrfx_cnf001_75deg_1 = cnf001_75deg_1.iloc[:,1]
lagtime_cnf001_75deg_2 = cnf001_75deg_2.iloc[:,0]
corrfx_cnf001_75deg_2 = cnf001_75deg_2.iloc[:,1]
lagtime_cnf001_75deg_3 = cnf001_75deg_3.iloc[:,0]
corrfx_cnf001_75deg_3 = cnf001_75deg_3.iloc[:,1]
lagtime_cnf001_75deg_4 = cnf001_75deg_4.iloc[:,0]
corrfx_cnf001_75deg_4 = cnf001_75deg_4.iloc[:,1]
lagtime_cnf001_75deg_5 = cnf001_75deg_5.iloc[:,0]
corrfx_cnf001_75deg_5 = cnf001_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_75deg_1 ,corrfx_cnf001_75deg_1)
plt.scatter(lagtime_cnf001_75deg_2 ,corrfx_cnf001_75deg_2)
plt.scatter(lagtime_cnf001_75deg_3 ,corrfx_cnf001_75deg_3)
plt.scatter(lagtime_cnf001_75deg_4 ,corrfx_cnf001_75deg_4)
plt.scatter(lagtime_cnf001_75deg_5 ,corrfx_cnf001_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.% CNF 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.% CNF", dpi=1500)
plt.show()

# %%
# [CNF] = 0.2wt.% at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf02_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.2CNF/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf02_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.2CNF/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf02_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.2CNF/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf02_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.2CNF/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf02_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.2CNF/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf02_75deg_1 = cnf02_75deg_1.iloc[:,0]
corrfx_cnf02_75deg_1 = cnf02_75deg_1.iloc[:,1]
lagtime_cnf02_75deg_2 = cnf02_75deg_2.iloc[:,0]
corrfx_cnf02_75deg_2 = cnf02_75deg_2.iloc[:,1]
lagtime_cnf02_75deg_3 = cnf02_75deg_3.iloc[:,0]
corrfx_cnf02_75deg_3 = cnf02_75deg_3.iloc[:,1]
lagtime_cnf02_75deg_4 = cnf02_75deg_4.iloc[:,0]
corrfx_cnf02_75deg_4 = cnf02_75deg_4.iloc[:,1]
lagtime_cnf02_75deg_5 = cnf02_75deg_5.iloc[:,0]
corrfx_cnf02_75deg_5 = cnf02_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf02_75deg_1 ,corrfx_cnf02_75deg_1)
plt.scatter(lagtime_cnf02_75deg_2 ,corrfx_cnf02_75deg_2)
plt.scatter(lagtime_cnf02_75deg_3 ,corrfx_cnf02_75deg_3)
plt.scatter(lagtime_cnf02_75deg_4 ,corrfx_cnf02_75deg_4)
plt.scatter(lagtime_cnf02_75deg_5 ,corrfx_cnf02_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.2wt.%CNF 75\u00b0')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# [CNF] = 0.55wt.% at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf055_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.55CNF/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf055_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.55CNF/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf055_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.55CNF/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf055_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.55CNF/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf055_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.55CNF/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf055_75deg_1 = cnf055_75deg_1.iloc[:,0]
corrfx_cnf055_75deg_1 = cnf055_75deg_1.iloc[:,1]
lagtime_cnf055_75deg_2 = cnf055_75deg_2.iloc[:,0]
corrfx_cnf055_75deg_2 = cnf055_75deg_2.iloc[:,1]
lagtime_cnf055_75deg_3 = cnf055_75deg_3.iloc[:,0]
corrfx_cnf055_75deg_3 = cnf055_75deg_3.iloc[:,1]
lagtime_cnf055_75deg_4 = cnf055_75deg_4.iloc[:,0]
corrfx_cnf055_75deg_4 = cnf055_75deg_4.iloc[:,1]
lagtime_cnf055_75deg_5 = cnf055_75deg_5.iloc[:,0]
corrfx_cnf055_75deg_5 = cnf055_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf055_75deg_1 ,corrfx_cnf055_75deg_1)
plt.scatter(lagtime_cnf055_75deg_2 ,corrfx_cnf055_75deg_2)
plt.scatter(lagtime_cnf055_75deg_3 ,corrfx_cnf055_75deg_3)
plt.scatter(lagtime_cnf055_75deg_4 ,corrfx_cnf055_75deg_4)
plt.scatter(lagtime_cnf055_75deg_5 ,corrfx_cnf055_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.55wt.%CNF 75\u00b0')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
plt.style.use('seaborn-paper')

plt.scatter(lagtime_cnf001_75deg_1 ,corrfx_cnf001_75deg_1, label = '0.01wt.%CNF')
plt.scatter(lagtime_cnf02_75deg_1 ,corrfx_cnf02_75deg_1, label = '0.2wt.%CNF')
plt.scatter(lagtime_cnf055_75deg_2 ,corrfx_cnf055_75deg_2, label = '0.55wt.%CNF')
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(frameon=False)
plt.title('Correlation function VS lag time Neat CNF 75\u00b0')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_001_75_1 = lagtime_cnf001_75deg_1
g_t_001_75_1 = corrfx_cnf001_75deg_1
t_02_75_1 = lagtime_cnf02_75deg_1
g_t_02_75_1 = corrfx_cnf02_75deg_1
t_055_75_2 = lagtime_cnf055_75deg_2
g_t_055_75_2 = corrfx_cnf055_75deg_2

p0 = [1, 1, 1]

params_001_75_1, cov_001_75_1 = curve_fit(g, t_001_75_1, g_t_001_75_1, p0)
A_fit_001_75_1, tau_fit_001_75_1, beta_fit_001_75_1 = params_001_75_1
print('Fitted parameters:')
print('A_001_75_1 =', A_fit_001_75_1)
print('tau_001_75_1 =', tau_fit_001_75_1)
print('beta_001_75_1 =', beta_fit_001_75_1)
params_02_75_1, cov_02_75_1 = curve_fit(g, t_02_75_1, g_t_02_75_1, p0)
A_fit_02_75_1, tau_fit_02_75_1, beta_fit_02_75_1 = params_02_75_1
print('Fitted parameters:')
print('A_02_75_1 =', A_fit_02_75_1)
print('tau_02_75_1 =', tau_fit_02_75_1)
print('beta_02_75_1 =', beta_fit_02_75_1)
params_055_75_2, cov_055_75_2 = curve_fit(g, t_055_75_2, g_t_055_75_2, p0)
A_fit_055_75_2, tau_fit_055_75_2, beta_fit_055_75_2 = params_055_75_2
print('Fitted parameters:')
print('A_055_75_2 =', A_fit_055_75_2)
print('tau_055_75_2 =', tau_fit_055_75_2)
print('beta_055_75_2 =', beta_fit_055_75_2)

t_fit_001_75_1 = np.logspace(-8, 1, 1000)
g_fit_001_75_1 = g(t_fit_001_75_1, A_fit_001_75_1, tau_fit_001_75_1, beta_fit_001_75_1)
t_fit_02_75_1 = np.logspace(-8, 1, 1000)
g_fit_02_75_1 = g(t_fit_02_75_1, A_fit_02_75_1, tau_fit_02_75_1, beta_fit_02_75_1)
t_fit_055_75_2 = np.logspace(-8, 1, 1000)
g_fit_055_75_2 = g(t_fit_055_75_2, A_fit_055_75_2, tau_fit_055_75_2, beta_fit_055_75_2)
# Out:
# Fitted parameters:
# A_001_75_1 = 0.20297873088119728
# tau_001_75_1 = 0.0017989436854514147
# beta_001_75_1 = 0.8018811749625687
# Fitted parameters:
# A_02_75_1 = 0.2017051597845348
# tau_02_75_1 = 0.0013500008179631838
# beta_02_75_1 = 0.6541909897025201
# Fitted parameters:
# A_055_75_2 = 0.19370113982474968
# tau_055_75_2 = 0.0024784008411282725
# beta_055_75_2 = 0.5233301186245677

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

plt.scatter(t_001_75_1 ,g_t_001_75_1, label = '0.01wt.%CNF')
plt.semilogx(t_fit_001_75_1, g_fit_001_75_1, 'k-', label='Fit 1')
plt.scatter(t_02_75_1 ,g_t_02_75_1, label = '0.2wt.%CNF')
plt.semilogx(t_fit_02_75_1, g_fit_02_75_1, 'k-.', label='Fit 1')
plt.scatter(t_055_75_2 ,g_t_055_75_2, label = '0.55wt.%CNF')
plt.semilogx(t_fit_055_75_2, g_fit_055_75_2, 'k--', label='Fit 1')
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Neat CNF: Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# 75 degree different repititions
cnfcon = [0.01, 0.2, 0.55]
tau = [tau_fit_001_75_1, tau_fit_02_75_1, tau_fit_055_75_1]
plt.style.use('_mpl-gallery')
plt.scatter(cnfcon, tau)
plt.xlabel('[CNF]')
plt.ylabel('\u03C4 [s]')
plt.yscale("log")

# %%
def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_001_75_1 = lagtime_cnf001_75deg_1
g_t_001_75_1 = corrfx_cnf001_75deg_1
t_001_75_2 = lagtime_cnf001_75deg_2
g_t_001_75_2 = corrfx_cnf001_75deg_2
t_001_75_3 = lagtime_cnf001_75deg_3
g_t_001_75_3 = corrfx_cnf001_75deg_3
t_001_75_4 = lagtime_cnf001_75deg_4
g_t_001_75_4 = corrfx_cnf001_75deg_4
t_001_75_5 = lagtime_cnf001_75deg_5
g_t_001_75_5 = corrfx_cnf001_75deg_5

t_02_75_1 = lagtime_cnf02_75deg_1
g_t_02_75_1 = corrfx_cnf02_75deg_1
t_02_75_2 = lagtime_cnf02_75deg_2
g_t_02_75_2 = corrfx_cnf02_75deg_2
t_02_75_3 = lagtime_cnf02_75deg_3
g_t_02_75_3 = corrfx_cnf02_75deg_3
t_02_75_4 = lagtime_cnf02_75deg_4
g_t_02_75_4 = corrfx_cnf02_75deg_4
t_02_75_5 = lagtime_cnf02_75deg_5
g_t_02_75_5 = corrfx_cnf02_75deg_5

t_055_75_1 = lagtime_cnf055_75deg_1
g_t_055_75_1 = corrfx_cnf055_75deg_1
t_055_75_2 = lagtime_cnf055_75deg_2
g_t_055_75_2 = corrfx_cnf055_75deg_2
t_055_75_3 = lagtime_cnf055_75deg_3
g_t_055_75_3 = corrfx_cnf055_75deg_3
t_055_75_4 = lagtime_cnf055_75deg_4
g_t_055_75_4 = corrfx_cnf055_75deg_4
t_055_75_5 = lagtime_cnf055_75deg_5
g_t_055_75_5 = corrfx_cnf055_75deg_5

p0 = [1, 1, 1]

params_001_75_1, cov_001_75_1 = curve_fit(g, t_001_75_1, g_t_001_75_1, p0)
A_fit_001_75_1, tau_fit_001_75_1, beta_fit_001_75_1 = params_001_75_1
params_001_75_2, cov_001_75_2 = curve_fit(g, t_001_75_2, g_t_001_75_2, p0)
A_fit_001_75_2, tau_fit_001_75_2, beta_fit_001_75_2 = params_001_75_2
params_001_75_3, cov_001_75_3 = curve_fit(g, t_001_75_3, g_t_001_75_3, p0)
A_fit_001_75_3, tau_fit_001_75_3, beta_fit_001_75_3 = params_001_75_3
params_001_75_4, cov_001_75_4 = curve_fit(g, t_001_75_4, g_t_001_75_4, p0)
A_fit_001_75_4, tau_fit_001_75_4, beta_fit_001_75_4 = params_001_75_4
params_001_75_5, cov_001_75_5 = curve_fit(g, t_001_75_5, g_t_001_75_5, p0)
A_fit_001_75_5, tau_fit_001_75_5, beta_fit_001_75_5 = params_001_75_5

params_02_75_1, cov_02_75_1 = curve_fit(g, t_02_75_1, g_t_02_75_1, p0)
A_fit_02_75_1, tau_fit_02_75_1, beta_fit_02_75_1 = params_02_75_1
params_02_75_2, cov_02_75_2 = curve_fit(g, t_02_75_2, g_t_02_75_2, p0)
A_fit_02_75_2, tau_fit_02_75_2, beta_fit_02_75_2 = params_02_75_2
params_02_75_3, cov_02_75_3 = curve_fit(g, t_02_75_3, g_t_02_75_3, p0)
A_fit_02_75_3, tau_fit_02_75_3, beta_fit_02_75_3 = params_02_75_3
params_02_75_4, cov_02_75_4 = curve_fit(g, t_02_75_4, g_t_02_75_4, p0)
A_fit_02_75_4, tau_fit_02_75_4, beta_fit_02_75_4 = params_02_75_4
params_02_75_5, cov_02_75_5 = curve_fit(g, t_02_75_5, g_t_02_75_5, p0)
A_fit_02_75_5, tau_fit_02_75_5, beta_fit_02_75_5 = params_02_75_5

params_055_75_1, cov_055_75_1 = curve_fit(g, t_055_75_1, g_t_055_75_1, p0)
A_fit_055_75_1, tau_fit_055_75_1, beta_fit_055_75_1 = params_055_75_1
params_055_75_2, cov_055_75_2 = curve_fit(g, t_055_75_2, g_t_055_75_2, p0)
A_fit_055_75_2, tau_fit_055_75_2, beta_fit_055_75_2 = params_055_75_2
params_055_75_3, cov_055_75_3 = curve_fit(g, t_055_75_3, g_t_055_75_3, p0)
A_fit_055_75_3, tau_fit_055_75_3, beta_fit_055_75_3 = params_055_75_3
params_055_75_4, cov_055_75_4 = curve_fit(g, t_055_75_4, g_t_055_75_4, p0)
A_fit_055_75_4, tau_fit_055_75_4, beta_fit_055_75_4 = params_055_75_4
params_055_75_5, cov_055_75_5 = curve_fit(g, t_055_75_5, g_t_055_75_5, p0)
A_fit_055_75_5, tau_fit_055_75_5, beta_fit_055_75_5 = params_055_75_5


t_fit_001_75_1 = np.logspace(-8, 1, 1000)
g_fit_001_75_1 = g(t_fit_001_75_1, A_fit_001_75_1, tau_fit_001_75_1, beta_fit_001_75_1)
t_fit_001_75_2 = np.logspace(-8, 1, 1000)
g_fit_001_75_2 = g(t_fit_001_75_2, A_fit_001_75_2, tau_fit_001_75_2, beta_fit_001_75_2)
t_fit_001_75_3 = np.logspace(-8, 1, 1000)
g_fit_001_75_3 = g(t_fit_001_75_3, A_fit_001_75_3, tau_fit_001_75_3, beta_fit_001_75_3)
t_fit_001_75_4 = np.logspace(-8, 1, 1000)
g_fit_001_75_4 = g(t_fit_001_75_4, A_fit_001_75_4, tau_fit_001_75_4, beta_fit_001_75_4)
t_fit_001_75_5 = np.logspace(-8, 1, 1000)
g_fit_001_75_5 = g(t_fit_001_75_5, A_fit_001_75_5, tau_fit_001_75_5, beta_fit_001_75_5)

t_fit_02_75_1 = np.logspace(-8, 1, 1000)
g_fit_02_75_1 = g(t_fit_02_75_1, A_fit_02_75_1, tau_fit_02_75_1, beta_fit_02_75_1)
t_fit_02_75_2 = np.logspace(-8, 1, 1000)
g_fit_02_75_2 = g(t_fit_02_75_2, A_fit_02_75_2, tau_fit_02_75_2, beta_fit_02_75_2)
t_fit_02_75_3 = np.logspace(-8, 1, 1000)
g_fit_02_75_3 = g(t_fit_02_75_3, A_fit_02_75_3, tau_fit_02_75_3, beta_fit_02_75_3)
t_fit_02_75_4 = np.logspace(-8, 1, 1000)
g_fit_02_75_4 = g(t_fit_02_75_4, A_fit_02_75_4, tau_fit_02_75_4, beta_fit_02_75_4)
t_fit_02_75_5 = np.logspace(-8, 1, 1000)
g_fit_02_75_5 = g(t_fit_02_75_5, A_fit_02_75_5, tau_fit_02_75_5, beta_fit_02_75_5)

t_fit_055_75_1 = np.logspace(-8, 1, 1000)
g_fit_055_75_1 = g(t_fit_055_75_1, A_fit_055_75_1, tau_fit_055_75_1, beta_fit_055_75_1)
t_fit_055_75_2 = np.logspace(-8, 1, 1000)
g_fit_055_75_2 = g(t_fit_055_75_2, A_fit_055_75_2, tau_fit_055_75_2, beta_fit_055_75_2)
t_fit_055_75_3 = np.logspace(-8, 1, 1000)
g_fit_055_75_3 = g(t_fit_055_75_3, A_fit_055_75_3, tau_fit_055_75_3, beta_fit_055_75_3)
t_fit_055_75_4 = np.logspace(-8, 1, 1000)
g_fit_055_75_4 = g(t_fit_055_75_4, A_fit_055_75_4, tau_fit_055_75_4, beta_fit_055_75_4)
t_fit_055_75_5 = np.logspace(-8, 1, 1000)
g_fit_055_75_5 = g(t_fit_055_75_5, A_fit_055_75_5, tau_fit_055_75_5, beta_fit_055_75_5)

tau_001_75 = [tau_fit_001_75_1, tau_fit_001_75_2, tau_fit_001_75_3, tau_fit_001_75_4, tau_fit_001_75_5]
Avg_tau_001_75 = np.mean(tau_001_75)
print('Average relaxation time 0.01wt.%CNF =', Avg_tau_001_75)
tau_02_75 = [tau_fit_02_75_1, tau_fit_02_75_2, tau_fit_02_75_3, tau_fit_02_75_4, tau_fit_02_75_5]
Avg_tau_02_75 = np.mean(tau_02_75)
print('Average relaxation time 0.2wt.%CNF =', Avg_tau_02_75)
tau_055_75 = [tau_fit_055_75_1, tau_fit_055_75_2, tau_fit_055_75_3, tau_fit_055_75_4, tau_fit_055_75_5]
Avg_tau_055_75 = np.mean(tau_055_75)
print('Average relaxation time 0.55wt.%CNF =', Avg_tau_055_75)

plt.style.use('_mpl-gallery')

D = [tau_001_75, tau_02_75, tau_055_75]
# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

#ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       #ylim=(0, 8), yticks=np.arange(1, 8))
plt.xlabel('[CNF]')
plt.ylabel('\u03C4 [s]')
plt.yscale("log")
plt.show()
# Out:
# Average relaxation time 0.01wt.%CNF = 0.0018344174229194658
# Average relaxation time 0.2wt.%CNF = 0.00963237764434181
# Average relaxation time 0.55wt.%CNF = 0.0026603983792853163
