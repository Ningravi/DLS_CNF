# %%
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import scipy as sp

# %%
# [CNF] = 0.01wt.% 0mMNaCl at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 4
cnf001_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_75deg_1 = cnf001_75deg_1.iloc[:,0]
corrfx_cnf001_75deg_1 = cnf001_75deg_1.iloc[:,1]
lagtime_cnf001_75deg_2 = cnf001_75deg_2.iloc[:,0]
corrfx_cnf001_75deg_2 = cnf001_75deg_2.iloc[:,1]
lagtime_cnf001_75deg_3 = cnf001_75deg_3.iloc[:,0]
corrfx_cnf001_75deg_3 = cnf001_75deg_3.iloc[:,1]
lagtime_cnf001_75deg_4 = cnf001_75deg_4.iloc[:,0]
corrfx_cnf001_75deg_4 = cnf001_75deg_4.iloc[:,1]
lagtime_cnf001_75deg_5 = cnf001_75deg_5.iloc[:,0]
corrfx_cnf001_75deg_5 = cnf001_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_75deg_1 ,corrfx_cnf001_75deg_1)
plt.scatter(lagtime_cnf001_75deg_2 ,corrfx_cnf001_75deg_2)
plt.scatter(lagtime_cnf001_75deg_3 ,corrfx_cnf001_75deg_3)
plt.scatter(lagtime_cnf001_75deg_4 ,corrfx_cnf001_75deg_4)
plt.scatter(lagtime_cnf001_75deg_5 ,corrfx_cnf001_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.% CNF 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.%CNF", dpi=1500)
plt.show()

# %%
# [CNF] = 0.01wt.% 2.5mMNaCl at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_25mMNaCl_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF2.5mMNaCl/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_25mMNaCl_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF2.5mMNaCl/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_25mMNaCl_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF2.5mMNaCl/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_25mMNaCl_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF2.5mMNaCl/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_25mMNaCl_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF2.5mMNaCl/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_25mMNaCl_75deg_1 = cnf001_25mMNaCl_75deg_1.iloc[:,0]
corrfx_cnf001_25mMNaCl_75deg_1 = cnf001_25mMNaCl_75deg_1.iloc[:,1]
lagtime_cnf001_25mMNaCl_75deg_2 = cnf001_25mMNaCl_75deg_2.iloc[:,0]
corrfx_cnf001_25mMNaCl_75deg_2 = cnf001_25mMNaCl_75deg_2.iloc[:,1]
lagtime_cnf001_25mMNaCl_75deg_3 = cnf001_25mMNaCl_75deg_3.iloc[:,0]
corrfx_cnf001_25mMNaCl_75deg_3 = cnf001_25mMNaCl_75deg_3.iloc[:,1]
lagtime_cnf001_25mMNaCl_75deg_4 = cnf001_25mMNaCl_75deg_4.iloc[:,0]
corrfx_cnf001_25mMNaCl_75deg_4 = cnf001_25mMNaCl_75deg_4.iloc[:,1]
lagtime_cnf001_25mMNaCl_75deg_5 = cnf001_25mMNaCl_75deg_5.iloc[:,0]
corrfx_cnf001_25mMNaCl_75deg_5 = cnf001_25mMNaCl_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_25mMNaCl_75deg_1 ,corrfx_cnf001_25mMNaCl_75deg_1)
plt.scatter(lagtime_cnf001_25mMNaCl_75deg_2 ,corrfx_cnf001_25mMNaCl_75deg_2)
plt.scatter(lagtime_cnf001_25mMNaCl_75deg_3 ,corrfx_cnf001_25mMNaCl_75deg_3)
plt.scatter(lagtime_cnf001_25mMNaCl_75deg_4 ,corrfx_cnf001_25mMNaCl_75deg_4)
plt.scatter(lagtime_cnf001_25mMNaCl_75deg_5 ,corrfx_cnf001_25mMNaCl_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.%CNF 2.5mMNaCl 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.% CNF", dpi=1500)
plt.show()

# %%
# [CNF] = 0.01wt.% 5mMNaCl at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_5mMNaCl_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF5mMNaCl/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_5mMNaCl_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF5mMNaCl/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_5mMNaCl_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF5mMNaCl/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_5mMNaCl_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF5mMNaCl/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_5mMNaCl_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF5mMNaCl/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_5mMNaCl_75deg_1 = cnf001_5mMNaCl_75deg_1.iloc[:,0]
corrfx_cnf001_5mMNaCl_75deg_1 = cnf001_5mMNaCl_75deg_1.iloc[:,1]
lagtime_cnf001_5mMNaCl_75deg_2 = cnf001_5mMNaCl_75deg_2.iloc[:,0]
corrfx_cnf001_5mMNaCl_75deg_2 = cnf001_5mMNaCl_75deg_2.iloc[:,1]
lagtime_cnf001_5mMNaCl_75deg_3 = cnf001_5mMNaCl_75deg_3.iloc[:,0]
corrfx_cnf001_5mMNaCl_75deg_3 = cnf001_5mMNaCl_75deg_3.iloc[:,1]
lagtime_cnf001_5mMNaCl_75deg_4 = cnf001_5mMNaCl_75deg_4.iloc[:,0]
corrfx_cnf001_5mMNaCl_75deg_4 = cnf001_5mMNaCl_75deg_4.iloc[:,1]
lagtime_cnf001_5mMNaCl_75deg_5 = cnf001_5mMNaCl_75deg_5.iloc[:,0]
corrfx_cnf001_5mMNaCl_75deg_5 = cnf001_5mMNaCl_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_5mMNaCl_75deg_1 ,corrfx_cnf001_5mMNaCl_75deg_1)
plt.scatter(lagtime_cnf001_5mMNaCl_75deg_2 ,corrfx_cnf001_5mMNaCl_75deg_2)
plt.scatter(lagtime_cnf001_5mMNaCl_75deg_3 ,corrfx_cnf001_5mMNaCl_75deg_3)
plt.scatter(lagtime_cnf001_5mMNaCl_75deg_4 ,corrfx_cnf001_5mMNaCl_75deg_4)
plt.scatter(lagtime_cnf001_5mMNaCl_75deg_5 ,corrfx_cnf001_5mMNaCl_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.%CNF 5mMNaCl 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.% CNF", dpi=1500)
plt.show()

# %%
# [CNF] = 0.01wt.% 10mMNaCl at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_10mMNaCl_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF10mMNaCl/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_10mMNaCl_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF10mMNaCl/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_10mMNaCl_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF10mMNaCl/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_10mMNaCl_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF10mMNaCl/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_10mMNaCl_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF10mMNaCl/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_10mMNaCl_75deg_1 = cnf001_10mMNaCl_75deg_1.iloc[:,0]
corrfx_cnf001_10mMNaCl_75deg_1 = cnf001_10mMNaCl_75deg_1.iloc[:,1]
lagtime_cnf001_10mMNaCl_75deg_2 = cnf001_10mMNaCl_75deg_2.iloc[:,0]
corrfx_cnf001_10mMNaCl_75deg_2 = cnf001_10mMNaCl_75deg_2.iloc[:,1]
lagtime_cnf001_10mMNaCl_75deg_3 = cnf001_10mMNaCl_75deg_3.iloc[:,0]
corrfx_cnf001_10mMNaCl_75deg_3 = cnf001_10mMNaCl_75deg_3.iloc[:,1]
lagtime_cnf001_10mMNaCl_75deg_4 = cnf001_10mMNaCl_75deg_4.iloc[:,0]
corrfx_cnf001_10mMNaCl_75deg_4 = cnf001_10mMNaCl_75deg_4.iloc[:,1]
lagtime_cnf001_10mMNaCl_75deg_5 = cnf001_10mMNaCl_75deg_5.iloc[:,0]
corrfx_cnf001_10mMNaCl_75deg_5 = cnf001_10mMNaCl_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_10mMNaCl_75deg_1 ,corrfx_cnf001_10mMNaCl_75deg_1)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_2 ,corrfx_cnf001_10mMNaCl_75deg_2)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_3 ,corrfx_cnf001_10mMNaCl_75deg_3)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_4 ,corrfx_cnf001_10mMNaCl_75deg_4)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_5 ,corrfx_cnf001_10mMNaCl_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.%CNF 10mMNaCl 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.% CNF", dpi=1500)
plt.show()

# %%
# [CNF] = 0.01wt.% 50mMNaCl at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_50mMNaCl_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF50mMNaCl/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_50mMNaCl_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF50mMNaCl/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_50mMNaCl_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF50mMNaCl/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_50mMNaCl_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF50mMNaCl/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_50mMNaCl_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF50mMNaCl/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_50mMNaCl_75deg_1 = cnf001_50mMNaCl_75deg_1.iloc[:,0]
corrfx_cnf001_50mMNaCl_75deg_1 = cnf001_50mMNaCl_75deg_1.iloc[:,1]
lagtime_cnf001_50mMNaCl_75deg_2 = cnf001_50mMNaCl_75deg_2.iloc[:,0]
corrfx_cnf001_50mMNaCl_75deg_2 = cnf001_50mMNaCl_75deg_2.iloc[:,1]
lagtime_cnf001_50mMNaCl_75deg_3 = cnf001_50mMNaCl_75deg_3.iloc[:,0]
corrfx_cnf001_50mMNaCl_75deg_3 = cnf001_50mMNaCl_75deg_3.iloc[:,1]
lagtime_cnf001_50mMNaCl_75deg_4 = cnf001_50mMNaCl_75deg_4.iloc[:,0]
corrfx_cnf001_50mMNaCl_75deg_4 = cnf001_50mMNaCl_75deg_4.iloc[:,1]
lagtime_cnf001_50mMNaCl_75deg_5 = cnf001_50mMNaCl_75deg_5.iloc[:,0]
corrfx_cnf001_50mMNaCl_75deg_5 = cnf001_50mMNaCl_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_50mMNaCl_75deg_1 ,corrfx_cnf001_50mMNaCl_75deg_1)
plt.scatter(lagtime_cnf001_50mMNaCl_75deg_2 ,corrfx_cnf001_50mMNaCl_75deg_2)
plt.scatter(lagtime_cnf001_50mMNaCl_75deg_3 ,corrfx_cnf001_50mMNaCl_75deg_3)
plt.scatter(lagtime_cnf001_50mMNaCl_75deg_4 ,corrfx_cnf001_50mMNaCl_75deg_4)
plt.scatter(lagtime_cnf001_50mMNaCl_75deg_5 ,corrfx_cnf001_50mMNaCl_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.%CNF 50mMNaCl 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.% CNF", dpi=1500)
plt.show()

# %%
# [CNF] = 0.01wt.% 100mMNaCl at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_100mMNaCl_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF100mMNaCl/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_100mMNaCl_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF100mMNaCl/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_100mMNaCl_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF100mMNaCl/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_100mMNaCl_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF100mMNaCl/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_100mMNaCl_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF100mMNaCl/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_100mMNaCl_75deg_1 = cnf001_100mMNaCl_75deg_1.iloc[:,0]
corrfx_cnf001_100mMNaCl_75deg_1 = cnf001_100mMNaCl_75deg_1.iloc[:,1]
lagtime_cnf001_100mMNaCl_75deg_2 = cnf001_100mMNaCl_75deg_2.iloc[:,0]
corrfx_cnf001_100mMNaCl_75deg_2 = cnf001_100mMNaCl_75deg_2.iloc[:,1]
lagtime_cnf001_100mMNaCl_75deg_3 = cnf001_100mMNaCl_75deg_3.iloc[:,0]
corrfx_cnf001_100mMNaCl_75deg_3 = cnf001_100mMNaCl_75deg_3.iloc[:,1]
lagtime_cnf001_100mMNaCl_75deg_4 = cnf001_100mMNaCl_75deg_4.iloc[:,0]
corrfx_cnf001_100mMNaCl_75deg_4 = cnf001_100mMNaCl_75deg_4.iloc[:,1]
lagtime_cnf001_100mMNaCl_75deg_5 = cnf001_100mMNaCl_75deg_5.iloc[:,0]
corrfx_cnf001_100mMNaCl_75deg_5 = cnf001_100mMNaCl_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_10mMNaCl_75deg_1 ,corrfx_cnf001_10mMNaCl_75deg_1)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_2 ,corrfx_cnf001_10mMNaCl_75deg_2)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_3 ,corrfx_cnf001_10mMNaCl_75deg_3)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_4 ,corrfx_cnf001_10mMNaCl_75deg_4)
plt.scatter(lagtime_cnf001_10mMNaCl_75deg_5 ,corrfx_cnf001_10mMNaCl_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time 0.01wt.%CNF 100mMNaCl 75\u00b0')
#plt.savefig("Correlation function VS lag time 0.01wt.% CNF", dpi=1500)
plt.show()
