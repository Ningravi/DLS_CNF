# %%
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import scipy as sp

# %%
# Summary of [CNF]=0.01% at different angles
cnf001 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/0.01CNF.csv', header= None, skiprows=[0,1,2,3,4])
angle_cnf001 = cnf001.iloc[:,13]
rh_cnf001 = cnf001.iloc[:, 3]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(angle_cnf001 ,rh_cnf001)
plt.xlabel('q [\u00b0]')
plt.ylabel('R\u0304\u2095 [nm]')
plt.title('Mean hydrodynamic radius VS Scattering angle for [CNF]=0.01wt.% ')
#plt.savefig("Mean hydrodynamic radius VS Scattering angle_0.01CNF.png", dpi=1500)
plt.show()

# %%
# [CNF] = 0.01wt.% at 30 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 1
cnf001_30deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 1/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_30deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 1/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_30deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 1/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_30deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 1/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_30deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 1/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

# assign parameters
lagtime_cnf001_30deg_1 = cnf001_30deg_1.iloc[:,0]
corrfx_cnf001_30deg_1 = cnf001_30deg_1.iloc[:,1]
lagtime_cnf001_30deg_2 = cnf001_30deg_2.iloc[:,0]
corrfx_cnf001_30deg_2 = cnf001_30deg_2.iloc[:,1]
lagtime_cnf001_30deg_3 = cnf001_30deg_3.iloc[:,0]
corrfx_cnf001_30deg_3 = cnf001_30deg_3.iloc[:,1]
lagtime_cnf001_30deg_4 = cnf001_30deg_4.iloc[:,0]
corrfx_cnf001_30deg_4 = cnf001_30deg_4.iloc[:,1]
lagtime_cnf001_30deg_5 = cnf001_30deg_5.iloc[:,0]
corrfx_cnf001_30deg_5 = cnf001_30deg_5.iloc[:,1]

# plot all repititions
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_30deg_1 ,corrfx_cnf001_30deg_1)
plt.scatter(lagtime_cnf001_30deg_2 ,corrfx_cnf001_30deg_2)
plt.scatter(lagtime_cnf001_30deg_3 ,corrfx_cnf001_30deg_3)
plt.scatter(lagtime_cnf001_30deg_4 ,corrfx_cnf001_30deg_4)
plt.scatter(lagtime_cnf001_30deg_5 ,corrfx_cnf001_30deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time of 0.01wt.% CNF at 30 degree')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_30_1 = lagtime_cnf001_30deg_1
g_t_30_1 = corrfx_cnf001_30deg_1
t_30_2 = lagtime_cnf001_30deg_2
g_t_30_2 = corrfx_cnf001_30deg_2
t_30_3 = lagtime_cnf001_30deg_3
g_t_30_3 = corrfx_cnf001_30deg_3
t_30_4 = lagtime_cnf001_30deg_4
g_t_30_4 = corrfx_cnf001_30deg_4
t_30_5 = lagtime_cnf001_30deg_5
g_t_30_5 = corrfx_cnf001_30deg_5

p0 = [1, 1, 1]

params_30_1, cov_30_1 = curve_fit(g, t_30_1, g_t_30_1, p0)
A_fit_30_1, tau_fit_30_1, beta_fit_30_1 = params_30_1
#print('Fitted parameters:')
#print('A_30_1 =', A_fit_30_1)
#print('tau_30_1 =', tau_fit_30_1)
#print('beta_30_1 =', beta_fit_30_1)
params_30_2, cov_30_2 = curve_fit(g, t_30_2, g_t_30_2, p0)
A_fit_30_2, tau_fit_30_2, beta_fit_30_2 = params_30_2
#print('Fitted parameters:')
#print('A_30_2 =', A_fit_30_2)
#print('tau_30_2 =', tau_fit_30_2)
#print('beta_30_2 =', beta_fit_30_2)
params_30_3, cov_30_3 = curve_fit(g, t_30_3, g_t_30_3, p0)
A_fit_30_3, tau_fit_30_3, beta_fit_30_3 = params_30_3
#print('Fitted parameters:')
#print('A_30_3 =', A_fit_30_3)
#print('tau_30_3 =', tau_fit_30_3)
#print('beta_30_3 =', beta_fit_30_3)
params_30_4, cov_30_4 = curve_fit(g, t_30_4, g_t_30_4, p0)
A_fit_30_4, tau_fit_30_4, beta_fit_30_4 = params_30_4
#print('Fitted parameters:')
#print('A_30_4 =', A_fit_30_4)
#print('tau_30_4 =', tau_fit_30_4)
#print('beta_30_4 =', beta_fit_30_4)
params_30_5, cov_30_5 = curve_fit(g, t_30_5, g_t_30_5, p0)
A_fit_30_5, tau_fit_30_5, beta_fit_30_5 = params_30_5
#print('Fitted parameters:')
#print('A_30_5 =', A_fit_30_5)
#print('tau_30_5 =', tau_fit_30_5)
#print('beta_30_5 =', beta_fit_30_5)

# Fit the data 
t_fit_30_1 = np.logspace(-8, 1, 1000)
g_fit_30_1 = g(t_fit_30_1, A_fit_30_1, tau_fit_30_1, beta_fit_30_1)
t_fit_30_2 = np.logspace(-8, 1, 1000)
g_fit_30_2 = g(t_fit_30_2, A_fit_30_2, tau_fit_30_2, beta_fit_30_2)
t_fit_30_3 = np.logspace(-8, 1, 1000)
g_fit_30_3 = g(t_fit_30_3, A_fit_30_3, tau_fit_30_3, beta_fit_30_3)
t_fit_30_4 = np.logspace(-8, 1, 1000)
g_fit_30_4 = g(t_fit_30_4, A_fit_30_4, tau_fit_30_4, beta_fit_30_4)
t_fit_30_5 = np.logspace(-8, 1, 1000)
g_fit_30_5 = g(t_fit_30_5, A_fit_30_5, tau_fit_30_5, beta_fit_30_5)
t_fit_30_6 = np.logspace(-8, 1, 1000)

plt.style.use('seaborn-paper')
plt.scatter(t_30_1, g_t_30_1, label='Repitition 1')
plt.semilogx(t_fit_30_1, g_fit_30_1, 'r-', label='Fit 1')
plt.scatter(t_30_2, g_t_30_2, label='Repitition 2')
plt.semilogx(t_fit_30_2, g_fit_30_2, 'r-', label='Fit 2')
plt.scatter(t_30_3, g_t_30_3, label='Repitition 3')
plt.semilogx(t_fit_30_3, g_fit_30_3, 'r-', label='Fit 3')
plt.scatter(t_30_4, g_t_30_4, label='Repitition 4')
plt.semilogx(t_fit_30_4, g_fit_30_4, 'r-', label='Fit 4')
plt.scatter(t_30_5, g_t_30_5, label='Repitition 5')
plt.semilogx(t_fit_30_5, g_fit_30_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()

# %%
# correct g^2(t)-1 to g(t) but the fitting looks werid

corrfx_cnf001_30deg_1_t = corrfx_cnf001_30deg_1+1
def gt(t1, A1, tau1, beta1):
    return A1 * np.exp(-(t1/tau1)**beta1)
t_30_t = lagtime_cnf001_30deg_1
g_t_30_t = corrfx_cnf001_30deg_1_t

p0_t = [1, 10, 1]

paramst, cov = curve_fit(gt, t_30_t, g_t_30_t, p0_t)
A_fitt, tau_fitt, beta_fitt = paramst
print('Fitted parameters:')
print('A =', A_fitt)
print('tau =', tau_fitt)
print('beta =', beta_fitt)

t_fitt = np.logspace(-8, 1, 1000)
g_fitt = g(t_fitt, A_fitt, tau_fitt, beta_fitt)

plt.style.use('seaborn-paper')
plt.scatter(t_30_t, g_t_30_t, label='Repitition 1')
plt.semilogx(t_fitt, g_fitt, 'r-', label='Fit')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g(t)')
plt.legend(frameon=False)
plt.show()
# Out:
# Fitted parameters:
# A = 1.3527115008901172
# tau = 56099363.77223405
# beta = 0.07798514214851958

# %%
# [CNF] = 0.01wt.% at 45 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 2
cnf001_45deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 2/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_45deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 2/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_45deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 2/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_45deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 2/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_45deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 2/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_45deg_1 = cnf001_45deg_1.iloc[:,0]
corrfx_cnf001_45deg_1 = cnf001_45deg_1.iloc[:,1]
lagtime_cnf001_45deg_2 = cnf001_45deg_2.iloc[:,0]
corrfx_cnf001_45deg_2 = cnf001_45deg_2.iloc[:,1]
lagtime_cnf001_45deg_3 = cnf001_45deg_3.iloc[:,0]
corrfx_cnf001_45deg_3 = cnf001_45deg_3.iloc[:,1]
lagtime_cnf001_45deg_4 = cnf001_45deg_4.iloc[:,0]
corrfx_cnf001_45deg_4 = cnf001_45deg_4.iloc[:,1]
lagtime_cnf001_45deg_5 = cnf001_45deg_5.iloc[:,0]
corrfx_cnf001_45deg_5 = cnf001_45deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_45deg_1 ,corrfx_cnf001_45deg_1)
plt.scatter(lagtime_cnf001_45deg_2 ,corrfx_cnf001_45deg_2)
plt.scatter(lagtime_cnf001_45deg_3 ,corrfx_cnf001_45deg_3)
plt.scatter(lagtime_cnf001_45deg_4 ,corrfx_cnf001_45deg_4)
plt.scatter(lagtime_cnf001_45deg_5 ,corrfx_cnf001_45deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_45_1 = lagtime_cnf001_45deg_1
g_t_45_1 = corrfx_cnf001_45deg_1
t_45_2 = lagtime_cnf001_45deg_2
g_t_45_2 = corrfx_cnf001_45deg_2
t_45_3 = lagtime_cnf001_45deg_3
g_t_45_3 = corrfx_cnf001_45deg_3
t_45_4 = lagtime_cnf001_45deg_4
g_t_45_4 = corrfx_cnf001_45deg_4
t_45_5 = lagtime_cnf001_45deg_5
g_t_45_5 = corrfx_cnf001_45deg_5

p0 = [1, 1, 1]

params_45_1, cov_45_1 = curve_fit(g, t_45_1, g_t_45_1, p0)
A_fit_45_1, tau_fit_45_1, beta_fit_45_1 = params_45_1
#print('Fitted parameters:')
#print('A_45_1 =', A_fit_45_1)
#print('tau_45_1 =', tau_fit_45_1)
#print('beta_45_1 =', beta_fit_45_1)
params_45_2, cov_45_2 = curve_fit(g, t_45_2, g_t_45_2, p0)
A_fit_45_2, tau_fit_45_2, beta_fit_45_2 = params_45_2
#print('Fitted parameters:')
#print('A_45_2 =', A_fit_45_2)
#print('tau_45_2 =', tau_fit_45_2)
#print('beta_45_2 =', beta_fit_45_2)
params_45_3, cov_45_3 = curve_fit(g, t_45_3, g_t_45_3, p0)
A_fit_45_3, tau_fit_45_3, beta_fit_45_3 = params_45_3
#print('Fitted parameters:')
#print('A_45_3 =', A_fit_45_3)
#print('tau_45_3 =', tau_fit_45_3)
#print('beta_45_3 =', beta_fit_45_3)
params_45_4, cov_45_4 = curve_fit(g, t_45_4, g_t_45_4, p0)
A_fit_45_4, tau_fit_45_4, beta_fit_45_4 = params_45_4
#print('Fitted parameters:')
#print('A_45_4 =', A_fit_45_4)
#print('tau_45_4 =', tau_fit_45_4)
#print('beta_45_4 =', beta_fit_45_4)
params_45_5, cov_45_5 = curve_fit(g, t_45_5, g_t_45_5, p0)
A_fit_45_5, tau_fit_45_5, beta_fit_45_5 = params_45_5
#print('Fitted parameters:')
#print('A_45_5 =', A_fit_45_5)
#print('tau_45_5 =', tau_fit_45_5)
#print('beta_45_5 =', beta_fit_45_5)

# Find an average time relaxation ot tau
tau_45 = [tau_fit_45_1, tau_fit_45_2, tau_fit_45_3, tau_fit_45_4, tau_fit_45_5]
Avg_tau_45 = np.mean(tau_45)
print("Avg relaxation time at 45 degree =", Avg_tau_45)

# Fit the data 
t_fit_45_1 = np.logspace(-8, 1, 1000)
g_fit_45_1 = g(t_fit_45_1, A_fit_45_1, tau_fit_45_1, beta_fit_45_1)
t_fit_45_2 = np.logspace(-8, 1, 1000)
g_fit_45_2 = g(t_fit_45_2, A_fit_45_2, tau_fit_45_2, beta_fit_45_2)
t_fit_45_3 = np.logspace(-8, 1, 1000)
g_fit_45_3 = g(t_fit_45_3, A_fit_45_3, tau_fit_45_3, beta_fit_45_3)
t_fit_45_4 = np.logspace(-8, 1, 1000)
g_fit_45_4 = g(t_fit_45_4, A_fit_45_4, tau_fit_45_4, beta_fit_45_4)
t_fit_45_5 = np.logspace(-8, 1, 1000)
g_fit_45_5 = g(t_fit_45_5, A_fit_45_5, tau_fit_45_5, beta_fit_45_5)
t_fit_45_6 = np.logspace(-8, 1, 1000)

plt.style.use('seaborn-paper')
plt.scatter(t_45_1, g_t_45_1, label='Repitition 1')
plt.semilogx(t_fit_45_1, g_fit_45_1, 'r-', label='Fit 1')
plt.scatter(t_45_2, g_t_45_2, label='Repitition 2')
plt.semilogx(t_fit_45_2, g_fit_45_2, 'r-', label='Fit 2')
plt.scatter(t_45_3, g_t_45_3, label='Repitition 3')
plt.semilogx(t_fit_45_3, g_fit_45_3, 'r-', label='Fit 3')
plt.scatter(t_45_4, g_t_45_4, label='Repitition 4')
plt.semilogx(t_fit_45_4, g_fit_45_4, 'r-', label='Fit 4')
plt.scatter(t_45_5, g_t_45_5, label='Repitition 5')
plt.semilogx(t_fit_45_5, g_fit_45_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()
# Out:
# Avg relaxation time at 45 degree = 0.008064107137732571

# %%
# [CNF] = 0.01wt.% at 60 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_60deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 3/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_60deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 3/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_60deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 3/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_60deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 3/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_60deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 3/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_60deg_1 = cnf001_60deg_1.iloc[:,0]
corrfx_cnf001_60deg_1 = cnf001_60deg_1.iloc[:,1]
lagtime_cnf001_60deg_2 = cnf001_60deg_2.iloc[:,0]
corrfx_cnf001_60deg_2 = cnf001_60deg_2.iloc[:,1]
lagtime_cnf001_60deg_3 = cnf001_60deg_3.iloc[:,0]
corrfx_cnf001_60deg_3 = cnf001_60deg_3.iloc[:,1]
lagtime_cnf001_60deg_4 = cnf001_60deg_4.iloc[:,0]
corrfx_cnf001_60deg_4 = cnf001_60deg_4.iloc[:,1]
lagtime_cnf001_60deg_5 = cnf001_60deg_5.iloc[:,0]
corrfx_cnf001_60deg_5 = cnf001_60deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_60deg_1 ,corrfx_cnf001_60deg_1)
plt.scatter(lagtime_cnf001_60deg_2 ,corrfx_cnf001_60deg_2)
plt.scatter(lagtime_cnf001_60deg_3 ,corrfx_cnf001_60deg_3)
plt.scatter(lagtime_cnf001_60deg_4 ,corrfx_cnf001_60deg_4)
plt.scatter(lagtime_cnf001_60deg_5 ,corrfx_cnf001_60deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_60_1 = lagtime_cnf001_60deg_1
g_t_60_1 = corrfx_cnf001_60deg_1
t_60_2 = lagtime_cnf001_60deg_2
g_t_60_2 = corrfx_cnf001_60deg_2
t_60_3 = lagtime_cnf001_60deg_3
g_t_60_3 = corrfx_cnf001_60deg_3
t_60_4 = lagtime_cnf001_60deg_4
g_t_60_4 = corrfx_cnf001_60deg_4
t_60_5 = lagtime_cnf001_60deg_5
g_t_60_5 = corrfx_cnf001_60deg_5

p0 = [1, 1, 1]

params_60_1, cov_60_1 = curve_fit(g, t_60_1, g_t_60_1, p0)
A_fit_60_1, tau_fit_60_1, beta_fit_60_1 = params_60_1
# print('Fitted parameters:')
# print('A_60_1 =', A_fit_60_1)
# print('tau_60_1 =', tau_fit_60_1)
# print('beta_60_1 =', beta_fit_60_1)
params_60_2, cov_60_2 = curve_fit(g, t_60_2, g_t_60_2, p0)
A_fit_60_2, tau_fit_60_2, beta_fit_60_2 = params_60_2
# print('Fitted parameters:')
# print('A_60_2 =', A_fit_60_2)
# print('tau_60_2 =', tau_fit_60_2)
# print('beta_60_2 =', beta_fit_60_2)
params_60_3, cov_60_3 = curve_fit(g, t_60_3, g_t_60_3, p0)
A_fit_60_3, tau_fit_60_3, beta_fit_60_3 = params_60_3
# print('Fitted parameters:')
# print('A_60_3 =', A_fit_60_3)
# print('tau_60_3 =', tau_fit_60_3)
# print('beta_60_3 =', beta_fit_60_3)
params_60_4, cov_60_4 = curve_fit(g, t_60_4, g_t_60_4, p0)
A_fit_60_4, tau_fit_60_4, beta_fit_60_4 = params_60_4
# print('Fitted parameters:')
# print('A_60_4 =', A_fit_60_4)
# print('tau_60_4 =', tau_fit_60_4)
# print('beta_60_4 =', beta_fit_60_4)
params_60_5, cov_60_5 = curve_fit(g, t_60_5, g_t_60_5, p0)
A_fit_60_5, tau_fit_60_5, beta_fit_60_5 = params_60_5
# print('Fitted parameters:')
# print('A_60_5 =', A_fit_60_5)
# print('tau_60_5 =', tau_fit_60_5)
# print('beta_60_5 =', beta_fit_60_5)

# Fit the data 
t_fit_60_1 = np.logspace(-8, 1, 1000)
g_fit_60_1 = g(t_fit_60_1, A_fit_60_1, tau_fit_60_1, beta_fit_60_1)
t_fit_60_2 = np.logspace(-8, 1, 1000)
g_fit_60_2 = g(t_fit_60_2, A_fit_60_2, tau_fit_60_2, beta_fit_60_2)
t_fit_60_3 = np.logspace(-8, 1, 1000)
g_fit_60_3 = g(t_fit_60_3, A_fit_60_3, tau_fit_60_3, beta_fit_60_3)
t_fit_60_4 = np.logspace(-8, 1, 1000)
g_fit_60_4 = g(t_fit_60_4, A_fit_60_4, tau_fit_60_4, beta_fit_60_4)
t_fit_60_5 = np.logspace(-8, 1, 1000)
g_fit_60_5 = g(t_fit_60_5, A_fit_60_5, tau_fit_60_5, beta_fit_60_5)
t_fit_60_6 = np.logspace(-8, 1, 1000)

plt.style.use('seaborn-paper')
plt.scatter(t_60_1, g_t_60_1, label='Repitition 1')
plt.semilogx(t_fit_60_1, g_fit_60_1, 'r-', label='Fit 1')
plt.scatter(t_60_2, g_t_60_2, label='Repitition 2')
plt.semilogx(t_fit_60_2, g_fit_60_2, 'r-', label='Fit 2')
plt.scatter(t_60_3, g_t_60_3, label='Repitition 3')
plt.semilogx(t_fit_60_3, g_fit_60_3, 'r-', label='Fit 3')
plt.scatter(t_60_4, g_t_60_4, label='Repitition 4')
plt.semilogx(t_fit_60_4, g_fit_60_4, 'r-', label='Fit 4')
plt.scatter(t_60_5, g_t_60_5, label='Repitition 5')
plt.semilogx(t_fit_60_5, g_fit_60_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()

# %%
# [CNF] = 0.01wt.% at 75 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_75deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_75deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 4/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_75deg_1 = cnf001_75deg_1.iloc[:,0]
corrfx_cnf001_75deg_1 = cnf001_75deg_1.iloc[:,1]
lagtime_cnf001_75deg_2 = cnf001_75deg_2.iloc[:,0]
corrfx_cnf001_75deg_2 = cnf001_75deg_2.iloc[:,1]
lagtime_cnf001_75deg_3 = cnf001_75deg_3.iloc[:,0]
corrfx_cnf001_75deg_3 = cnf001_75deg_3.iloc[:,1]
lagtime_cnf001_75deg_4 = cnf001_75deg_4.iloc[:,0]
corrfx_cnf001_75deg_4 = cnf001_75deg_4.iloc[:,1]
lagtime_cnf001_75deg_5 = cnf001_75deg_5.iloc[:,0]
corrfx_cnf001_75deg_5 = cnf001_75deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_75deg_1 ,corrfx_cnf001_75deg_1)
plt.scatter(lagtime_cnf001_75deg_2 ,corrfx_cnf001_75deg_2)
plt.scatter(lagtime_cnf001_75deg_3 ,corrfx_cnf001_75deg_3)
plt.scatter(lagtime_cnf001_75deg_4 ,corrfx_cnf001_75deg_4)
plt.scatter(lagtime_cnf001_75deg_5 ,corrfx_cnf001_75deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_75_1 = lagtime_cnf001_75deg_1
g_t_75_1 = corrfx_cnf001_75deg_1
t_75_2 = lagtime_cnf001_75deg_2
g_t_75_2 = corrfx_cnf001_75deg_2
t_75_3 = lagtime_cnf001_75deg_3
g_t_75_3 = corrfx_cnf001_75deg_3
t_75_4 = lagtime_cnf001_75deg_4
g_t_75_4 = corrfx_cnf001_75deg_4
t_75_5 = lagtime_cnf001_75deg_5
g_t_75_5 = corrfx_cnf001_75deg_5

p0 = [1, 1, 1]

params_75_1, cov_75_1 = curve_fit(g, t_75_1, g_t_75_1, p0)
A_fit_75_1, tau_fit_75_1, beta_fit_75_1 = params_75_1
params_75_2, cov_75_2 = curve_fit(g, t_75_2, g_t_75_2, p0)
A_fit_75_2, tau_fit_75_2, beta_fit_75_2 = params_75_2
params_75_3, cov_75_3 = curve_fit(g, t_75_3, g_t_75_3, p0)
A_fit_75_3, tau_fit_75_3, beta_fit_75_3 = params_75_3
params_75_4, cov_75_4 = curve_fit(g, t_75_4, g_t_75_4, p0)
A_fit_75_4, tau_fit_75_4, beta_fit_75_4 = params_75_4
params_75_5, cov_75_5 = curve_fit(g, t_75_5, g_t_75_5, p0)
A_fit_75_5, tau_fit_75_5, beta_fit_75_5 = params_75_5

# Fit the data 
t_fit_75_1 = np.logspace(-8, 1, 1000)
g_fit_75_1 = g(t_fit_75_1, A_fit_75_1, tau_fit_75_1, beta_fit_75_1)
t_fit_75_2 = np.logspace(-8, 1, 1000)
g_fit_75_2 = g(t_fit_75_2, A_fit_75_2, tau_fit_75_2, beta_fit_75_2)
t_fit_75_3 = np.logspace(-8, 1, 1000)
g_fit_75_3 = g(t_fit_75_3, A_fit_75_3, tau_fit_75_3, beta_fit_75_3)
t_fit_75_4 = np.logspace(-8, 1, 1000)
g_fit_75_4 = g(t_fit_75_4, A_fit_75_4, tau_fit_75_4, beta_fit_75_4)
t_fit_75_5 = np.logspace(-8, 1, 1000)
g_fit_75_5 = g(t_fit_75_5, A_fit_75_5, tau_fit_75_5, beta_fit_75_5)
t_fit_75_6 = np.logspace(-8, 1, 1000)

plt.style.use('seaborn-paper')
plt.scatter(t_75_1, g_t_75_1, label='Repitition 1')
plt.semilogx(t_fit_75_1, g_fit_75_1, 'r-', label='Fit 1')
plt.scatter(t_75_2, g_t_75_2, label='Repitition 2')
plt.semilogx(t_fit_75_2, g_fit_75_2, 'r-', label='Fit 2')
plt.scatter(t_75_3, g_t_75_3, label='Repitition 3')
plt.semilogx(t_fit_75_3, g_fit_75_3, 'r-', label='Fit 3')
plt.scatter(t_75_4, g_t_75_4, label='Repitition 4')
plt.semilogx(t_fit_75_4, g_fit_75_4, 'r-', label='Fit 4')
plt.scatter(t_75_5, g_t_75_5, label='Repitition 5')
plt.semilogx(t_fit_75_5, g_fit_75_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()

# %%
# [CNF] = 0.01wt.% at 90 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 3
cnf001_90deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 5/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_90deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 5/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_90deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 5/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_90deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 5/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_90deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 5/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_90deg_1 = cnf001_90deg_1.iloc[:,0]
corrfx_cnf001_90deg_1 = cnf001_90deg_1.iloc[:,1]
lagtime_cnf001_90deg_2 = cnf001_90deg_2.iloc[:,0]
corrfx_cnf001_90deg_2 = cnf001_90deg_2.iloc[:,1]
lagtime_cnf001_90deg_3 = cnf001_90deg_3.iloc[:,0]
corrfx_cnf001_90deg_3 = cnf001_90deg_3.iloc[:,1]
lagtime_cnf001_90deg_4 = cnf001_90deg_4.iloc[:,0]
corrfx_cnf001_90deg_4 = cnf001_90deg_4.iloc[:,1]
lagtime_cnf001_90deg_5 = cnf001_90deg_5.iloc[:,0]
corrfx_cnf001_90deg_5 = cnf001_90deg_5.iloc[:,1]

import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_90deg_1 ,corrfx_cnf001_90deg_1)
plt.scatter(lagtime_cnf001_90deg_2 ,corrfx_cnf001_90deg_2)
plt.scatter(lagtime_cnf001_90deg_3 ,corrfx_cnf001_90deg_3)
plt.scatter(lagtime_cnf001_90deg_4 ,corrfx_cnf001_90deg_4)
plt.scatter(lagtime_cnf001_90deg_5 ,corrfx_cnf001_90deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_90_1 = lagtime_cnf001_90deg_1
g_t_90_1 = corrfx_cnf001_90deg_1
t_90_2 = lagtime_cnf001_90deg_2
g_t_90_2 = corrfx_cnf001_90deg_2
t_90_3 = lagtime_cnf001_90deg_3
g_t_90_3 = corrfx_cnf001_90deg_3
t_90_4 = lagtime_cnf001_90deg_4
g_t_90_4 = corrfx_cnf001_90deg_4
t_90_5 = lagtime_cnf001_90deg_5
g_t_90_5 = corrfx_cnf001_90deg_5

p0 = [1, 1, 1]

params_90_1, cov_90_1 = curve_fit(g, t_90_1, g_t_90_1, p0)
A_fit_90_1, tau_fit_90_1, beta_fit_90_1 = params_90_1
params_90_2, cov_90_2 = curve_fit(g, t_90_2, g_t_90_2, p0)
A_fit_90_2, tau_fit_90_2, beta_fit_90_2 = params_90_2
params_90_3, cov_90_3 = curve_fit(g, t_90_3, g_t_90_3, p0)
A_fit_90_3, tau_fit_90_3, beta_fit_90_3 = params_90_3
params_90_4, cov_90_4 = curve_fit(g, t_90_4, g_t_90_4, p0)
A_fit_90_4, tau_fit_90_4, beta_fit_90_4 = params_90_4
params_90_5, cov_90_5 = curve_fit(g, t_90_5, g_t_90_5, p0)
A_fit_90_5, tau_fit_90_5, beta_fit_90_5 = params_90_5

# Fit the data 
t_fit_90_1 = np.logspace(-8, 1, 1000)
g_fit_90_1 = g(t_fit_90_1, A_fit_90_1, tau_fit_90_1, beta_fit_90_1)
t_fit_90_2 = np.logspace(-8, 1, 1000)
g_fit_90_2 = g(t_fit_90_2, A_fit_90_2, tau_fit_90_2, beta_fit_90_2)
t_fit_90_3 = np.logspace(-8, 1, 1000)
g_fit_90_3 = g(t_fit_90_3, A_fit_90_3, tau_fit_90_3, beta_fit_90_3)
t_fit_90_4 = np.logspace(-8, 1, 1000)
g_fit_90_4 = g(t_fit_90_4, A_fit_90_4, tau_fit_90_4, beta_fit_90_4)
t_fit_90_5 = np.logspace(-8, 1, 1000)
g_fit_90_5 = g(t_fit_90_5, A_fit_90_5, tau_fit_90_5, beta_fit_90_5)
t_fit_90_6 = np.logspace(-8, 1, 1000)

tau_90 = [tau_fit_90_1, tau_fit_90_2, tau_fit_90_3, tau_fit_90_4, tau_fit_90_5]
Avg_tau_90 = np.mean(tau_90)
print("Avg relaxation time at 90 degree =", Avg_tau_90)


plt.style.use('seaborn-paper')
plt.scatter(t_90_1, g_t_90_1, label='Repitition 1')
plt.semilogx(t_fit_90_1, g_fit_90_1, 'r-', label='Fit 1')
plt.scatter(t_90_2, g_t_90_2, label='Repitition 2')
plt.semilogx(t_fit_90_2, g_fit_90_2, 'r-', label='Fit 2')
plt.scatter(t_90_3, g_t_90_3, label='Repitition 3')
plt.semilogx(t_fit_90_3, g_fit_90_3, 'r-', label='Fit 3')
plt.scatter(t_90_4, g_t_90_4, label='Repitition 4')
plt.semilogx(t_fit_90_4, g_fit_90_4, 'r-', label='Fit 4')
plt.scatter(t_90_5, g_t_90_5, label='Repitition 5')
plt.semilogx(t_fit_90_5, g_fit_90_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()
# Out:
# Avg relaxation time at 90 degree = 0.00268702361271979

# %%
# [CNF] = 0.01wt.% at 105 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 6
cnf001_105deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 6/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_105deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 6/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_105deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 6/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_105deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 6/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_105deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 6/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_105deg_1 = cnf001_105deg_1.iloc[:,0]
corrfx_cnf001_105deg_1 = cnf001_105deg_1.iloc[:,1]
lagtime_cnf001_105deg_2 = cnf001_105deg_2.iloc[:,0]
corrfx_cnf001_105deg_2 = cnf001_105deg_2.iloc[:,1]
lagtime_cnf001_105deg_3 = cnf001_105deg_3.iloc[:,0]
corrfx_cnf001_105deg_3 = cnf001_105deg_3.iloc[:,1]
lagtime_cnf001_105deg_4 = cnf001_105deg_4.iloc[:,0]
corrfx_cnf001_105deg_4 = cnf001_105deg_4.iloc[:,1]
lagtime_cnf001_105deg_5 = cnf001_105deg_5.iloc[:,0]
corrfx_cnf001_105deg_5 = cnf001_105deg_5.iloc[:,1]
import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_105deg_1 ,corrfx_cnf001_105deg_1)
plt.scatter(lagtime_cnf001_105deg_2 ,corrfx_cnf001_105deg_2)
plt.scatter(lagtime_cnf001_105deg_3 ,corrfx_cnf001_105deg_3)
plt.scatter(lagtime_cnf001_105deg_4 ,corrfx_cnf001_105deg_4)
plt.scatter(lagtime_cnf001_105deg_5 ,corrfx_cnf001_105deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Correlation function VS lag time", dpi=1500)
plt.show()

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_105_1 = lagtime_cnf001_105deg_1
g_t_105_1 = corrfx_cnf001_105deg_1
t_105_2 = lagtime_cnf001_105deg_2
g_t_105_2 = corrfx_cnf001_105deg_2
t_105_3 = lagtime_cnf001_105deg_3
g_t_105_3 = corrfx_cnf001_105deg_3
t_105_4 = lagtime_cnf001_105deg_4
g_t_105_4 = corrfx_cnf001_105deg_4
t_105_5 = lagtime_cnf001_105deg_5
g_t_105_5 = corrfx_cnf001_105deg_5

p0 = [1, 1, 1]

params_105_1, cov_105_1 = curve_fit(g, t_105_1, g_t_105_1, p0)
A_fit_105_1, tau_fit_105_1, beta_fit_105_1 = params_105_1
params_105_2, cov_105_2 = curve_fit(g, t_105_2, g_t_105_2, p0)
A_fit_105_2, tau_fit_105_2, beta_fit_105_2 = params_105_2
params_105_3, cov_105_3 = curve_fit(g, t_105_3, g_t_105_3, p0)
A_fit_105_3, tau_fit_105_3, beta_fit_105_3 = params_105_3
params_105_4, cov_105_4 = curve_fit(g, t_105_4, g_t_105_4, p0)
A_fit_105_4, tau_fit_105_4, beta_fit_105_4 = params_105_4
params_105_5, cov_105_5 = curve_fit(g, t_105_5, g_t_105_5, p0)
A_fit_105_5, tau_fit_105_5, beta_fit_105_5 = params_105_5

# Fit the data 
t_fit_105_1 = np.logspace(-8, 1, 1000)
g_fit_105_1 = g(t_fit_105_1, A_fit_105_1, tau_fit_105_1, beta_fit_105_1)
t_fit_105_2 = np.logspace(-8, 1, 1000)
g_fit_105_2 = g(t_fit_105_2, A_fit_105_2, tau_fit_105_2, beta_fit_105_2)
t_fit_105_3 = np.logspace(-8, 1, 1000)
g_fit_105_3 = g(t_fit_105_3, A_fit_105_3, tau_fit_105_3, beta_fit_105_3)
t_fit_105_4 = np.logspace(-8, 1, 1000)
g_fit_105_4 = g(t_fit_105_4, A_fit_105_4, tau_fit_105_4, beta_fit_105_4)
t_fit_105_5 = np.logspace(-8, 1, 1000)
g_fit_105_5 = g(t_fit_105_5, A_fit_105_5, tau_fit_105_5, beta_fit_105_5)


tau_105 = [tau_fit_105_1, tau_fit_105_2, tau_fit_105_3, tau_fit_105_4, tau_fit_105_5]
Avg_tau_105 = np.mean(tau_105)
print("Avg relaxation time at 105 degree =", Avg_tau_105)


plt.style.use('seaborn-paper')
plt.scatter(t_105_1, g_t_105_1, label='Repitition 1')
plt.semilogx(t_fit_105_1, g_fit_105_1, 'r-', label='Fit 1')
plt.scatter(t_105_2, g_t_105_2, label='Repitition 2')
plt.semilogx(t_fit_105_2, g_fit_105_2, 'r-', label='Fit 2')
plt.scatter(t_105_3, g_t_105_3, label='Repitition 3')
plt.semilogx(t_fit_105_3, g_fit_105_3, 'r-', label='Fit 3')
plt.scatter(t_105_4, g_t_105_4, label='Repitition 4')
plt.semilogx(t_fit_105_4, g_fit_105_4, 'r-', label='Fit 4')
plt.scatter(t_105_5, g_t_105_5, label='Repitition 5')
plt.semilogx(t_fit_105_5, g_fit_105_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()
# Out:
# Avg relaxation time at 105 degree = 0.0011711659867090275

# %%
# [CNF] = 0.01wt.% at 120 degree, 20C
# import Correlation Function data from 0.01CNF Measurement 7
cnf001_120deg_1 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 7/Repetition1/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_120deg_2 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 7/Repetition2/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_120deg_3 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 7/Repetition3/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_120deg_4 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 7/Repetition4/Correlation Function.csv', header= None, skiprows=[0,1,2])
cnf001_120deg_5 = pd.read_csv('/Users/ningravi/Desktop/20230423/0.01CNF/Measurement 7/Repetition5/Correlation Function.csv', header= None, skiprows=[0,1,2])

lagtime_cnf001_120deg_1 = cnf001_120deg_1.iloc[:,0]
corrfx_cnf001_120deg_1 = cnf001_120deg_1.iloc[:,1]
lagtime_cnf001_120deg_2 = cnf001_120deg_2.iloc[:,0]
corrfx_cnf001_120deg_2 = cnf001_120deg_2.iloc[:,1]
lagtime_cnf001_120deg_3 = cnf001_120deg_3.iloc[:,0]
corrfx_cnf001_120deg_3 = cnf001_120deg_3.iloc[:,1]
lagtime_cnf001_120deg_4 = cnf001_120deg_4.iloc[:,0]
corrfx_cnf001_120deg_4 = cnf001_120deg_4.iloc[:,1]
lagtime_cnf001_120deg_5 = cnf001_120deg_5.iloc[:,0]
corrfx_cnf001_120deg_5 = cnf001_120deg_5.iloc[:,1]
import matplotlib.pyplot as plt
#from matplotlib import rcParams
plt.style.use('seaborn-paper')
#ncolors = len(plt.rcParams['axes.prop_cycle'])

plt.scatter(lagtime_cnf001_120deg_1 ,corrfx_cnf001_120deg_1)
plt.scatter(lagtime_cnf001_120deg_2 ,corrfx_cnf001_120deg_2)
plt.scatter(lagtime_cnf001_120deg_3 ,corrfx_cnf001_120deg_3)
plt.scatter(lagtime_cnf001_120deg_4 ,corrfx_cnf001_120deg_4)
plt.scatter(lagtime_cnf001_120deg_5 ,corrfx_cnf001_120deg_5)
plt.xlabel('\u03C4 [s]')
plt.ylabel('g\u00b2(t)-1')
plt.xscale("log")
plt.legend(['Repitition 1','Repitition 2','Repitition 3','Repitition 4','Repitition 5'], frameon=False)
plt.title('Correlation function VS lag time')
#plt.savefig("Correlation function VS lag time", dpi=1500)
#plt.show()
# Out:
# Text(0.5, 1.0, 'Correlation function VS lag time')

# %%
# Fitting to 𝑔(𝑡)=𝐴𝑒𝑥𝑝[−(𝑡/𝜏)^𝛽]

def g(t, A, tau, beta):
    return A * np.exp(-(t/tau)**beta)
t_120_1 = lagtime_cnf001_120deg_1
g_t_120_1 = corrfx_cnf001_120deg_1
t_120_2 = lagtime_cnf001_120deg_2
g_t_120_2 = corrfx_cnf001_120deg_2
t_120_3 = lagtime_cnf001_120deg_3
g_t_120_3 = corrfx_cnf001_120deg_3
t_120_4 = lagtime_cnf001_120deg_4
g_t_120_4 = corrfx_cnf001_120deg_4
t_120_5 = lagtime_cnf001_120deg_5
g_t_120_5 = corrfx_cnf001_120deg_5

p0 = [1, 1, 1]

params_120_1, cov_120_1 = curve_fit(g, t_120_1, g_t_120_1, p0)
A_fit_120_1, tau_fit_120_1, beta_fit_120_1 = params_120_1
params_120_2, cov_120_2 = curve_fit(g, t_120_2, g_t_120_2, p0)
A_fit_120_2, tau_fit_120_2, beta_fit_120_2 = params_120_2
params_120_3, cov_120_3 = curve_fit(g, t_120_3, g_t_120_3, p0)
A_fit_120_3, tau_fit_120_3, beta_fit_120_3 = params_120_3
params_120_4, cov_120_4 = curve_fit(g, t_120_4, g_t_120_4, p0)
A_fit_120_4, tau_fit_120_4, beta_fit_120_4 = params_120_4
params_120_5, cov_120_5 = curve_fit(g, t_120_5, g_t_120_5, p0)
A_fit_120_5, tau_fit_120_5, beta_fit_120_5 = params_120_5

# Fit the data 
t_fit_120_1 = np.logspace(-8, 1, 1000)
g_fit_120_1 = g(t_fit_120_1, A_fit_120_1, tau_fit_120_1, beta_fit_120_1)
t_fit_120_2 = np.logspace(-8, 1, 1000)
g_fit_120_2 = g(t_fit_120_2, A_fit_120_2, tau_fit_120_2, beta_fit_120_2)
t_fit_120_3 = np.logspace(-8, 1, 1000)
g_fit_120_3 = g(t_fit_120_3, A_fit_120_3, tau_fit_120_3, beta_fit_120_3)
t_fit_120_4 = np.logspace(-8, 1, 1000)
g_fit_120_4 = g(t_fit_120_4, A_fit_120_4, tau_fit_120_4, beta_fit_120_4)
t_fit_120_5 = np.logspace(-8, 1, 1000)
g_fit_120_5 = g(t_fit_120_5, A_fit_120_5, tau_fit_120_5, beta_fit_120_5)


tau_120 = [tau_fit_120_1, tau_fit_120_2, tau_fit_120_3, tau_fit_120_4, tau_fit_120_5]
Avg_tau_120 = np.mean(tau_120)
print("Avg relaxation time at 120 degree =", Avg_tau_120)


plt.style.use('seaborn-paper')
plt.scatter(t_120_1, g_t_120_1, label='Repitition 1')
plt.semilogx(t_fit_120_1, g_fit_120_1, 'r-', label='Fit 1')
plt.scatter(t_120_2, g_t_120_2, label='Repitition 2')
plt.semilogx(t_fit_120_2, g_fit_120_2, 'r-', label='Fit 2')
plt.scatter(t_120_3, g_t_120_3, label='Repitition 3')
plt.semilogx(t_fit_120_3, g_fit_120_3, 'r-', label='Fit 3')
plt.scatter(t_120_4, g_t_120_4, label='Repitition 4')
plt.semilogx(t_fit_120_4, g_fit_120_4, 'r-', label='Fit 4')
plt.scatter(t_120_5, g_t_120_5, label='Repitition 5')
plt.semilogx(t_fit_120_5, g_fit_120_5, 'r-', label='Fit 5')
plt.xscale("log")
plt.xlabel('t')
plt.ylabel('g\u00b2(t)-1')
plt.legend(frameon=False)
plt.show()
# Out:
# Avg relaxation time at 120 degree = 0.0006720117357633961

# %%
# Find an average time relaxation ot tau
tau_30 = [tau_fit_30_1, tau_fit_30_2, tau_fit_30_3, tau_fit_30_4, tau_fit_30_5]
Avg_tau_30 = np.mean(tau_30)
print("Avg relaxation time at 30 degree =", Avg_tau_30)
tau_45 = [tau_fit_45_1, tau_fit_45_2, tau_fit_45_3, tau_fit_45_4, tau_fit_45_5]
Avg_tau_45 = np.mean(tau_45)
print("Avg relaxation time at 45 degree =", Avg_tau_45)
tau_60 = [tau_fit_60_1, tau_fit_60_2, tau_fit_60_3, tau_fit_60_4, tau_fit_60_5]
Avg_tau_60 = np.mean(tau_60)
print("Avg relaxation time at 60 degree =", Avg_tau_60)
tau_75 = [tau_fit_75_1, tau_fit_75_2, tau_fit_75_3, tau_fit_75_4, tau_fit_75_5]
Avg_tau_75 = np.mean(tau_75)
print("Avg relaxation time at 75 degree =", Avg_tau_75)
tau_90 = [tau_fit_90_1, tau_fit_90_2, tau_fit_90_3, tau_fit_90_4, tau_fit_90_5]
Avg_tau_90 = np.mean(tau_90)
print("Avg relaxation time at 90 degree =", Avg_tau_90)
tau_105 = [tau_fit_105_1, tau_fit_105_2, tau_fit_105_3, tau_fit_105_4, tau_fit_105_5]
Avg_tau_105 = np.mean(tau_105)
print("Avg relaxation time at 105 degree =", Avg_tau_105)
tau_120 = [tau_fit_120_1, tau_fit_120_2, tau_fit_120_3, tau_fit_120_4, tau_fit_120_5]
Avg_tau_120 = np.mean(tau_120)
print("Avg relaxation time at 120 degree =", Avg_tau_120)

plt.style.use('seaborn-poster')

D = [tau_30, tau_45, tau_60, tau_75, tau_90, tau_105, tau_120]
# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[30, 45, 60, 75, 90, 105, 120], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

#ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       #ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# Avg relaxation time at 30 degree = 0.034411655835452415
# Avg relaxation time at 45 degree = 0.008064107137732571
# Avg relaxation time at 60 degree = 0.004162857865634799
# Avg relaxation time at 75 degree = 0.0018344174229194658
# Avg relaxation time at 90 degree = 0.00268702361271979
# Avg relaxation time at 105 degree = 0.0011711659867090275
# Avg relaxation time at 120 degree = 0.0006720117357633961
